# %% [markdown]
# ## RETRIEVE NASA API DATA

# %%
import requests
import csv
import time
import json
import numpy as np
import pandas as pd

# %%
# Step 1: Define bounding box (your region)
min_lat, max_lat = 41.644, 42.023
min_lon, max_lon = -87.525, -88.260
lat_step = 0.1
lon_step = 0.1

# Step 2: Create grid of points
latitudes = np.arange(min_lat, max_lat, lat_step)
longitudes = np.arange(min_lon, max_lon, lon_step)

# Valid parameters for monthly data
parameters = "ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT"

# Base API URL
base_url = "https://power.larc.nasa.gov/api/temporal/monthly/point"

# Step 3: Loop through each grid point and request data
all_data = []

for lat in latitudes:
    for lon in longitudes:
        print(f"Requesting data for ({lat:.3f}, {lon:.3f})...")
        url = (
            f"{base_url}?parameters={parameters}&community=RE"
            f"&longitude={lon:.3f}&latitude={lat:.3f}"
            f"&start=2019&end=2023&format=JSON"
        )

        try:
            response = requests.get(url)
            data = response.json()

            records = data["properties"]["parameter"]
            months = list(data["properties"]["parameter"][list(records.keys())[0]].keys())

            # Create DataFrame
            df = pd.DataFrame({
                "YearMonth": months,
                "Latitude": lat,
                "Longitude": lon
            })

            for param in records:
                df[param] = [records[param][month] for month in months]

            all_data.append(df)

            # Avoid hitting API too hard
            time.sleep(0.5)

        except Exception as e:
            print(f"Failed at ({lat:.3f}, {lon:.3f}): {e}")

# Step 4: Combine and save
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("solar_region_data_2019.csv", index=False)
print("All regional data saved to 'solar_region_data_2019.csv'")

# %%
# Step 1: Define bounding box (your region)
min_lat, max_lat = 41.644, 42.0236
min_lon, max_lon = -87.940, -87.523
lat_step = 0.01
lon_step = 0.01

# Step 2: Create grid of points
latitudes = np.arange(min_lat, max_lat, lat_step)
longitudes = np.arange(min_lon, max_lon, lon_step)

# Valid parameters for monthly data7
parameters = "ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT"

# Base API URL
base_url = "https://power.larc.nasa.gov/api/temporal/monthly/point"

# Step 3: Loop through each grid point and request data
all_data = []

for lat in latitudes:
    for lon in longitudes:
        print(f"Requesting data for ({lat:.3f}, {lon:.3f})...")
        url = (
            f"{base_url}?parameters={parameters}&community=RE"
            f"&longitude={lon:.3f}&latitude={lat:.3f}"
            f"&start=2019&end=2024&format=JSON"
        )

        try:
            response = requests.get(url)
            data = response.json()

            records = data["properties"]["parameter"]
            months = list(data["properties"]["parameter"][list(records.keys())[0]].keys())

            # Create DataFrame
            df = pd.DataFrame({
                "YearMonth": months,
                "Latitude": lat,
                "Longitude": lon
            })

            for param in records:
                df[param] = [records[param][month] for month in months]

            all_data.append(df)

            # Avoid hitting API too hard
            time.sleep(0.5)

        except Exception as e:
            print(f"Failed at ({lat:.3f}, {lon:.3f}): {e}")

# Step 4: Combine and save
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("chicago_solar_region_data1.csv", index=False)
print("All regional data saved to 'chicago_solar_region_data1.csv'")
# Out:
# Requesting data for (41.644, -87.940)...
# Requesting data for (41.644, -87.930)...
# Requesting data for (41.644, -87.920)...
# Requesting data for (41.644, -87.910)...
# Requesting data for (41.644, -87.900)...
# Requesting data for (41.644, -87.890)...
# Requesting data for (41.644, -87.880)...
# Requesting data for (41.644, -87.870)...
# Requesting data for (41.644, -87.860)...
# Requesting data for (41.644, -87.850)...
# Requesting data for (41.644, -87.840)...
# Requesting data for (41.644, -87.830)...
# Requesting data for (41.644, -87.820)...
# Requesting data for (41.644, -87.810)...
# Requesting data for (41.644, -87.800)...
# Requesting data for (41.644, -87.790)...
# Requesting data for (41.644, -87.780)...
# Requesting data for (41.644, -87.770)...
# Requesting data for (41.644, -87.760)...
# Requesting data for (41.644, -87.750)...
# Requesting data for (41.644, -87.740)...
# Requesting data for (41.644, -87.730)...
# Requesting data for (41.644, -87.720)...
# Requesting data for (41.644, -87.710)...
# Requesting data for (41.644, -87.700)...
# Requesting data for (41.644, -87.690)...
# Requesting data for (41.644, -87.680)...
# Requesting data for (41.644, -87.670)...
# Requesting data for (41.644, -87.660)...
# Requesting data for (41.644, -87.650)...
# Requesting data for (41.644, -87.640)...
# Requesting data for (41.644, -87.630)...
# Requesting data for (41.644, -87.620)...
# Requesting data for (41.644, -87.610)...
# Requesting data for (41.644, -87.600)...
# Requesting data for (41.644, -87.590)...
# Requesting data for (41.644, -87.580)...
# Requesting data for (41.644, -87.570)...
# Requesting data for (41.644, -87.560)...
# Requesting data for (41.644, -87.550)...
# Requesting data for (41.644, -87.540)...
# Requesting data for (41.644, -87.530)...
# Requesting data for (41.654, -87.940)...
# Requesting data for (41.654, -87.930)...
# Requesting data for (41.654, -87.920)...
# Requesting data for (41.654, -87.910)...
# Requesting data for (41.654, -87.900)...
# Requesting data for (41.654, -87.890)...
# Requesting data for (41.654, -87.880)...
# Requesting data for (41.654, -87.870)...
# Requesting data for (41.654, -87.860)...
# Requesting data for (41.654, -87.850)...
# Requesting data for (41.654, -87.840)...
# Requesting data for (41.654, -87.830)...
# Requesting data for (41.654, -87.820)...
# Requesting data for (41.654, -87.810)...
# Requesting data for (41.654, -87.800)...
# Requesting data for (41.654, -87.790)...
# Requesting data for (41.654, -87.780)...
# Requesting data for (41.654, -87.770)...
# Requesting data for (41.654, -87.760)...
# Requesting data for (41.654, -87.750)...
# Requesting data for (41.654, -87.740)...
# Requesting data for (41.654, -87.730)...
# Requesting data for (41.654, -87.720)...
# Requesting data for (41.654, -87.710)...
# Requesting data for (41.654, -87.700)...
# Requesting data for (41.654, -87.690)...
# Requesting data for (41.654, -87.680)...
# Requesting data for (41.654, -87.670)...
# Requesting data for (41.654, -87.660)...
# Requesting data for (41.654, -87.650)...
# Requesting data for (41.654, -87.640)...
# Requesting data for (41.654, -87.630)...
# Requesting data for (41.654, -87.620)...
# Requesting data for (41.654, -87.610)...
# Requesting data for (41.654, -87.600)...
# Requesting data for (41.654, -87.590)...
# Requesting data for (41.654, -87.580)...
# Requesting data for (41.654, -87.570)...
# Requesting data for (41.654, -87.560)...
# Requesting data for (41.654, -87.550)...
# Requesting data for (41.654, -87.540)...
# Requesting data for (41.654, -87.530)...
# Requesting data for (41.664, -87.940)...
# Requesting data for (41.664, -87.930)...
# Requesting data for (41.664, -87.920)...
# Requesting data for (41.664, -87.910)...
# Requesting data for (41.664, -87.900)...
# Requesting data for (41.664, -87.890)...
# Requesting data for (41.664, -87.880)...
# Requesting data for (41.664, -87.870)...
# Requesting data for (41.664, -87.860)...
# Requesting data for (41.664, -87.850)...
# Requesting data for (41.664, -87.840)...
# Requesting data for (41.664, -87.830)...
# Requesting data for (41.664, -87.820)...
# Requesting data for (41.664, -87.810)...
# Requesting data for (41.664, -87.800)...
# Requesting data for (41.664, -87.790)...
# Requesting data for (41.664, -87.780)...
# Requesting data for (41.664, -87.770)...
# Requesting data for (41.664, -87.760)...
# Requesting data for (41.664, -87.750)...
# Requesting data for (41.664, -87.740)...
# Requesting data for (41.664, -87.730)...
# Requesting data for (41.664, -87.720)...
# Requesting data for (41.664, -87.710)...
# Requesting data for (41.664, -87.700)...
# Requesting data for (41.664, -87.690)...
# Requesting data for (41.664, -87.680)...
# Requesting data for (41.664, -87.670)...
# Requesting data for (41.664, -87.660)...
# Requesting data for (41.664, -87.650)...
# Requesting data for (41.664, -87.640)...
# Requesting data for (41.664, -87.630)...
# Requesting data for (41.664, -87.620)...
# Requesting data for (41.664, -87.610)...
# Requesting data for (41.664, -87.600)...
# Requesting data for (41.664, -87.590)...
# Requesting data for (41.664, -87.580)...
# Requesting data for (41.664, -87.570)...
# Requesting data for (41.664, -87.560)...
# Requesting data for (41.664, -87.550)...
# Requesting data for (41.664, -87.540)...
# Requesting data for (41.664, -87.530)...
# Requesting data for (41.674, -87.940)...
# Requesting data for (41.674, -87.930)...
# Requesting data for (41.674, -87.920)...
# Requesting data for (41.674, -87.910)...
# Requesting data for (41.674, -87.900)...
# Requesting data for (41.674, -87.890)...
# Requesting data for (41.674, -87.880)...
# Requesting data for (41.674, -87.870)...
# Requesting data for (41.674, -87.860)...
# Requesting data for (41.674, -87.850)...
# Requesting data for (41.674, -87.840)...
# Requesting data for (41.674, -87.830)...
# Requesting data for (41.674, -87.820)...
# Requesting data for (41.674, -87.810)...
# Requesting data for (41.674, -87.800)...
# Requesting data for (41.674, -87.790)...
# Requesting data for (41.674, -87.780)...
# Requesting data for (41.674, -87.770)...
# Requesting data for (41.674, -87.760)...
# Requesting data for (41.674, -87.750)...
# Requesting data for (41.674, -87.740)...
# Requesting data for (41.674, -87.730)...
# Requesting data for (41.674, -87.720)...
# Requesting data for (41.674, -87.710)...
# Requesting data for (41.674, -87.700)...
# Requesting data for (41.674, -87.690)...
# Requesting data for (41.674, -87.680)...
# Requesting data for (41.674, -87.670)...
# Requesting data for (41.674, -87.660)...
# Requesting data for (41.674, -87.650)...
# Requesting data for (41.674, -87.640)...
# Requesting data for (41.674, -87.630)...
# Requesting data for (41.674, -87.620)...
# Requesting data for (41.674, -87.610)...
# Requesting data for (41.674, -87.600)...
# Requesting data for (41.674, -87.590)...
# Requesting data for (41.674, -87.580)...
# Requesting data for (41.674, -87.570)...
# Requesting data for (41.674, -87.560)...
# Requesting data for (41.674, -87.550)...
# Requesting data for (41.674, -87.540)...
# Requesting data for (41.674, -87.530)...
# Requesting data for (41.684, -87.940)...
# Requesting data for (41.684, -87.930)...
# Requesting data for (41.684, -87.920)...
# Requesting data for (41.684, -87.910)...
# Requesting data for (41.684, -87.900)...
# Requesting data for (41.684, -87.890)...
# Requesting data for (41.684, -87.880)...
# Requesting data for (41.684, -87.870)...
# Requesting data for (41.684, -87.860)...
# Requesting data for (41.684, -87.850)...
# Requesting data for (41.684, -87.840)...
# Requesting data for (41.684, -87.830)...
# Requesting data for (41.684, -87.820)...
# Requesting data for (41.684, -87.810)...
# Requesting data for (41.684, -87.800)...
# Requesting data for (41.684, -87.790)...
# Requesting data for (41.684, -87.780)...
# Requesting data for (41.684, -87.770)...
# Requesting data for (41.684, -87.760)...
# Requesting data for (41.684, -87.750)...
# Requesting data for (41.684, -87.740)...
# Requesting data for (41.684, -87.730)...
# Requesting data for (41.684, -87.720)...
# Requesting data for (41.684, -87.710)...
# Requesting data for (41.684, -87.700)...
# Requesting data for (41.684, -87.690)...
# Requesting data for (41.684, -87.680)...
# Requesting data for (41.684, -87.670)...
# Requesting data for (41.684, -87.660)...
# Requesting data for (41.684, -87.650)...
# Requesting data for (41.684, -87.640)...
# Requesting data for (41.684, -87.630)...
# Requesting data for (41.684, -87.620)...
# Requesting data for (41.684, -87.610)...
# Requesting data for (41.684, -87.600)...
# Requesting data for (41.684, -87.590)...
# Requesting data for (41.684, -87.580)...
# Requesting data for (41.684, -87.570)...
# Requesting data for (41.684, -87.560)...
# Requesting data for (41.684, -87.550)...
# Failed at (41.684, -87.550): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Requesting data for (41.684, -87.540)...
# Failed at (41.684, -87.540): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.540&latitude=41.684&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.684, -87.530)...
# Failed at (41.684, -87.530): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.530&latitude=41.684&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E080>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.940)...
# Failed at (41.694, -87.940): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.940&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.930)...
# Failed at (41.694, -87.930): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.930&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.920)...
# Failed at (41.694, -87.920): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.920&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E0B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.910)...
# Failed at (41.694, -87.910): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.910&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DEA0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.900)...
# Failed at (41.694, -87.900): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.900&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.890)...
# Failed at (41.694, -87.890): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.890&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.880)...
# Failed at (41.694, -87.880): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.880&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.870)...
# Failed at (41.694, -87.870): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.870&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E0E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.860)...
# Failed at (41.694, -87.860): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.860&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.850)...
# Failed at (41.694, -87.850): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.850&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DBD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.840)...
# Failed at (41.694, -87.840): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.840&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DB70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.830)...
# Failed at (41.694, -87.830): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.830&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.820)...
# Failed at (41.694, -87.820): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.820&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.810)...
# Failed at (41.694, -87.810): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.810&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6C490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.800)...
# Failed at (41.694, -87.800): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.800&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.790)...
# Failed at (41.694, -87.790): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.790&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.780)...
# Failed at (41.694, -87.780): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.780&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.770)...
# Failed at (41.694, -87.770): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.770&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DDB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.760)...
# Failed at (41.694, -87.760): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.760&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.750)...
# Failed at (41.694, -87.750): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.750&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6C1C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.740)...
# Failed at (41.694, -87.740): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.740&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.730)...
# Failed at (41.694, -87.730): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.730&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DED0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.720)...
# Failed at (41.694, -87.720): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.720&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.710)...
# Failed at (41.694, -87.710): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.710&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.700)...
# Failed at (41.694, -87.700): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.700&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E080>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.690)...
# Failed at (41.694, -87.690): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.690&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.680)...
# Failed at (41.694, -87.680): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.680&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.670)...
# Failed at (41.694, -87.670): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.670&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E0B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.660)...
# Failed at (41.694, -87.660): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.660&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DEA0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.650)...
# Failed at (41.694, -87.650): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.650&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E110>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.640)...
# Failed at (41.694, -87.640): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.640&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.630)...
# Failed at (41.694, -87.630): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.630&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DDE0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.620)...
# Failed at (41.694, -87.620): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.620&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6D1B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.610)...
# Failed at (41.694, -87.610): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.610&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.600)...
# Failed at (41.694, -87.600): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.600&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DBD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.590)...
# Failed at (41.694, -87.590): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.590&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DB70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.580)...
# Failed at (41.694, -87.580): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.580&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.570)...
# Failed at (41.694, -87.570): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.570&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.560)...
# Failed at (41.694, -87.560): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.560&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6C490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.550)...
# Failed at (41.694, -87.550): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.550&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.540)...
# Failed at (41.694, -87.540): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.540&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.694, -87.530)...
# Failed at (41.694, -87.530): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.530&latitude=41.694&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.940)...
# Failed at (41.704, -87.940): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.940&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.930)...
# Failed at (41.704, -87.930): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.930&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.920)...
# Failed at (41.704, -87.920): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.920&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6C1C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.910)...
# Failed at (41.704, -87.910): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.910&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.900)...
# Failed at (41.704, -87.900): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.900&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DCC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.890)...
# Failed at (41.704, -87.890): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.890&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DED0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.880)...
# Failed at (41.704, -87.880): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.880&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.870)...
# Failed at (41.704, -87.870): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.870&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E080>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.860)...
# Failed at (41.704, -87.860): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.860&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.850)...
# Failed at (41.704, -87.850): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.850&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.840)...
# Failed at (41.704, -87.840): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.840&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E0B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.830)...
# Failed at (41.704, -87.830): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.830&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DEA0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.820)...
# Failed at (41.704, -87.820): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.820&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6E110>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.810)...
# Failed at (41.704, -87.810): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.810&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.800)...
# Failed at (41.704, -87.800): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.800&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DDE0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.790)...
# Failed at (41.704, -87.790): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.790&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6D1B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.780)...
# Failed at (41.704, -87.780): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.780&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.770)...
# Failed at (41.704, -87.770): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.770&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DBD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.760)...
# Failed at (41.704, -87.760): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.760&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DB70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.750)...
# Failed at (41.704, -87.750): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.750&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.740)...
# Failed at (41.704, -87.740): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.740&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.730)...
# Failed at (41.704, -87.730): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.730&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DB40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.720)...
# Failed at (41.704, -87.720): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.720&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DF60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.710)...
# Failed at (41.704, -87.710): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.710&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DFF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.700)...
# Failed at (41.704, -87.700): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.700&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DD80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.690)...
# Failed at (41.704, -87.690): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.690&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DE40>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.680)...
# Failed at (41.704, -87.680): HTTPSConnectionPool(host='power.larc.nasa.gov', port=443): Max retries exceeded with url: /api/temporal/monthly/point?parameters=ALLSKY_SFC_SW_DWN,CLRSKY_SFC_SW_DWN,ALLSKY_SFC_SW_DNI,ALLSKY_KT,ALLSKY_SFC_LW_DWN,CLRSKY_SFC_PAR_TOT&community=RE&longitude=-87.680&latitude=41.704&start=2019&end=2024&format=JSON (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A55BA6DC30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requesting data for (41.704, -87.670)...
# ...
# Requesting data for (41.924, -87.620)...
# Requesting data for (41.924, -87.610)...
# Requesting data for (41.924, -87.600)...
# Requesting data for (41.924, -87.590)...
# Requesting data for (41.924, -87.580)...
# Requesting data for (41.924, -87.570)...
# Requesting data for (41.924, -87.560)...
# Requesting data for (41.924, -87.550)...
# Requesting data for (41.924, -87.540)...
# Requesting data for (41.924, -87.530)...
# Requesting data for (41.934, -87.940)...
# Requesting data for (41.934, -87.930)...
# Requesting data for (41.934, -87.920)...
# Requesting data for (41.934, -87.910)...
# Requesting data for (41.934, -87.900)...
# Requesting data for (41.934, -87.890)...
# Requesting data for (41.934, -87.880)...
# Requesting data for (41.934, -87.870)...
# Requesting data for (41.934, -87.860)...
# Requesting data for (41.934, -87.850)...
# Requesting data for (41.934, -87.840)...
# Requesting data for (41.934, -87.830)...
# Requesting data for (41.934, -87.820)...
# Requesting data for (41.934, -87.810)...
# Requesting data for (41.934, -87.800)...
# Requesting data for (41.934, -87.790)...
# Requesting data for (41.934, -87.780)...
# Requesting data for (41.934, -87.770)...
# Requesting data for (41.934, -87.760)...
# Requesting data for (41.934, -87.750)...
# Requesting data for (41.934, -87.740)...
# Requesting data for (41.934, -87.730)...
# Requesting data for (41.934, -87.720)...
# Requesting data for (41.934, -87.710)...
# Requesting data for (41.934, -87.700)...
# Requesting data for (41.934, -87.690)...
# Requesting data for (41.934, -87.680)...
# Requesting data for (41.934, -87.670)...
# Requesting data for (41.934, -87.660)...
# Requesting data for (41.934, -87.650)...
# Requesting data for (41.934, -87.640)...
# Requesting data for (41.934, -87.630)...
# Requesting data for (41.934, -87.620)...
# Requesting data for (41.934, -87.610)...
# Requesting data for (41.934, -87.600)...
# Requesting data for (41.934, -87.590)...
# Requesting data for (41.934, -87.580)...
# Requesting data for (41.934, -87.570)...
# Requesting data for (41.934, -87.560)...
# Requesting data for (41.934, -87.550)...
# Requesting data for (41.934, -87.540)...
# Requesting data for (41.934, -87.530)...
# Requesting data for (41.944, -87.940)...
# Requesting data for (41.944, -87.930)...
# Requesting data for (41.944, -87.920)...
# Requesting data for (41.944, -87.910)...
# Requesting data for (41.944, -87.900)...
# Requesting data for (41.944, -87.890)...
# Requesting data for (41.944, -87.880)...
# Requesting data for (41.944, -87.870)...
# Requesting data for (41.944, -87.860)...
# Requesting data for (41.944, -87.850)...
# Requesting data for (41.944, -87.840)...
# Requesting data for (41.944, -87.830)...
# Requesting data for (41.944, -87.820)...
# Requesting data for (41.944, -87.810)...
# Requesting data for (41.944, -87.800)...
# Requesting data for (41.944, -87.790)...
# Requesting data for (41.944, -87.780)...
# Requesting data for (41.944, -87.770)...
# Requesting data for (41.944, -87.760)...
# Requesting data for (41.944, -87.750)...
# Requesting data for (41.944, -87.740)...
# Requesting data for (41.944, -87.730)...
# Requesting data for (41.944, -87.720)...
# Requesting data for (41.944, -87.710)...
# Requesting data for (41.944, -87.700)...
# Requesting data for (41.944, -87.690)...
# Requesting data for (41.944, -87.680)...
# Requesting data for (41.944, -87.670)...
# Requesting data for (41.944, -87.660)...
# Requesting data for (41.944, -87.650)...
# Requesting data for (41.944, -87.640)...
# Requesting data for (41.944, -87.630)...
# Requesting data for (41.944, -87.620)...
# Requesting data for (41.944, -87.610)...
# Requesting data for (41.944, -87.600)...
# Requesting data for (41.944, -87.590)...
# Requesting data for (41.944, -87.580)...
# Requesting data for (41.944, -87.570)...
# Requesting data for (41.944, -87.560)...
# Requesting data for (41.944, -87.550)...
# Requesting data for (41.944, -87.540)...
# Requesting data for (41.944, -87.530)...
# Requesting data for (41.954, -87.940)...
# Requesting data for (41.954, -87.930)...
# Requesting data for (41.954, -87.920)...
# Requesting data for (41.954, -87.910)...
# Requesting data for (41.954, -87.900)...
# Requesting data for (41.954, -87.890)...
# Requesting data for (41.954, -87.880)...
# Requesting data for (41.954, -87.870)...
# Requesting data for (41.954, -87.860)...
# Requesting data for (41.954, -87.850)...
# Requesting data for (41.954, -87.840)...
# Requesting data for (41.954, -87.830)...
# Requesting data for (41.954, -87.820)...
# Requesting data for (41.954, -87.810)...
# Requesting data for (41.954, -87.800)...
# Requesting data for (41.954, -87.790)...
# Requesting data for (41.954, -87.780)...
# Requesting data for (41.954, -87.770)...
# Requesting data for (41.954, -87.760)...
# Requesting data for (41.954, -87.750)...
# Requesting data for (41.954, -87.740)...
# Requesting data for (41.954, -87.730)...
# Requesting data for (41.954, -87.720)...
# Requesting data for (41.954, -87.710)...
# Requesting data for (41.954, -87.700)...
# Requesting data for (41.954, -87.690)...
# Requesting data for (41.954, -87.680)...
# Requesting data for (41.954, -87.670)...
# Requesting data for (41.954, -87.660)...
# Requesting data for (41.954, -87.650)...
# Requesting data for (41.954, -87.640)...
# Requesting data for (41.954, -87.630)...
# Requesting data for (41.954, -87.620)...
# Requesting data for (41.954, -87.610)...
# Requesting data for (41.954, -87.600)...
# Requesting data for (41.954, -87.590)...
# Requesting data for (41.954, -87.580)...
# Requesting data for (41.954, -87.570)...
# Requesting data for (41.954, -87.560)...
# Requesting data for (41.954, -87.550)...
# Requesting data for (41.954, -87.540)...
# Requesting data for (41.954, -87.530)...
# Requesting data for (41.964, -87.940)...
# Requesting data for (41.964, -87.930)...
# Requesting data for (41.964, -87.920)...
# Requesting data for (41.964, -87.910)...
# Requesting data for (41.964, -87.900)...
# Requesting data for (41.964, -87.890)...
# Requesting data for (41.964, -87.880)...
# Requesting data for (41.964, -87.870)...
# Requesting data for (41.964, -87.860)...
# Requesting data for (41.964, -87.850)...
# Requesting data for (41.964, -87.840)...
# Requesting data for (41.964, -87.830)...
# Requesting data for (41.964, -87.820)...
# Requesting data for (41.964, -87.810)...
# Requesting data for (41.964, -87.800)...
# Requesting data for (41.964, -87.790)...
# Requesting data for (41.964, -87.780)...
# Requesting data for (41.964, -87.770)...
# Requesting data for (41.964, -87.760)...
# Requesting data for (41.964, -87.750)...
# Requesting data for (41.964, -87.740)...
# Requesting data for (41.964, -87.730)...
# Requesting data for (41.964, -87.720)...
# Requesting data for (41.964, -87.710)...
# Requesting data for (41.964, -87.700)...
# Requesting data for (41.964, -87.690)...
# Requesting data for (41.964, -87.680)...
# Requesting data for (41.964, -87.670)...
# Requesting data for (41.964, -87.660)...
# Requesting data for (41.964, -87.650)...
# Requesting data for (41.964, -87.640)...
# Requesting data for (41.964, -87.630)...
# Requesting data for (41.964, -87.620)...
# Requesting data for (41.964, -87.610)...
# Requesting data for (41.964, -87.600)...
# Requesting data for (41.964, -87.590)...
# Requesting data for (41.964, -87.580)...
# Requesting data for (41.964, -87.570)...
# Requesting data for (41.964, -87.560)...
# Requesting data for (41.964, -87.550)...
# Requesting data for (41.964, -87.540)...
# Requesting data for (41.964, -87.530)...
# Requesting data for (41.974, -87.940)...
# Requesting data for (41.974, -87.930)...
# Requesting data for (41.974, -87.920)...
# Requesting data for (41.974, -87.910)...
# Requesting data for (41.974, -87.900)...
# Requesting data for (41.974, -87.890)...
# Requesting data for (41.974, -87.880)...
# Requesting data for (41.974, -87.870)...
# Requesting data for (41.974, -87.860)...
# Requesting data for (41.974, -87.850)...
# Requesting data for (41.974, -87.840)...
# Requesting data for (41.974, -87.830)...
# Requesting data for (41.974, -87.820)...
# Requesting data for (41.974, -87.810)...
# Requesting data for (41.974, -87.800)...
# Requesting data for (41.974, -87.790)...
# Requesting data for (41.974, -87.780)...
# Requesting data for (41.974, -87.770)...
# Requesting data for (41.974, -87.760)...
# Requesting data for (41.974, -87.750)...
# Requesting data for (41.974, -87.740)...
# Requesting data for (41.974, -87.730)...
# Requesting data for (41.974, -87.720)...
# Requesting data for (41.974, -87.710)...
# Requesting data for (41.974, -87.700)...
# Requesting data for (41.974, -87.690)...
# Requesting data for (41.974, -87.680)...
# Requesting data for (41.974, -87.670)...
# Requesting data for (41.974, -87.660)...
# Requesting data for (41.974, -87.650)...
# Requesting data for (41.974, -87.640)...
# Requesting data for (41.974, -87.630)...
# Requesting data for (41.974, -87.620)...
# Requesting data for (41.974, -87.610)...
# Requesting data for (41.974, -87.600)...
# Requesting data for (41.974, -87.590)...
# Requesting data for (41.974, -87.580)...
# Requesting data for (41.974, -87.570)...
# Requesting data for (41.974, -87.560)...
# Requesting data for (41.974, -87.550)...
# Requesting data for (41.974, -87.540)...
# Requesting data for (41.974, -87.530)...
# Requesting data for (41.984, -87.940)...
# Requesting data for (41.984, -87.930)...
# Requesting data for (41.984, -87.920)...
# Requesting data for (41.984, -87.910)...
# Requesting data for (41.984, -87.900)...
# Requesting data for (41.984, -87.890)...
# Requesting data for (41.984, -87.880)...
# Requesting data for (41.984, -87.870)...
# Requesting data for (41.984, -87.860)...
# Requesting data for (41.984, -87.850)...
# Requesting data for (41.984, -87.840)...
# Requesting data for (41.984, -87.830)...
# Requesting data for (41.984, -87.820)...
# Requesting data for (41.984, -87.810)...
# Requesting data for (41.984, -87.800)...
# Requesting data for (41.984, -87.790)...
# Requesting data for (41.984, -87.780)...
# Requesting data for (41.984, -87.770)...
# Requesting data for (41.984, -87.760)...
# Requesting data for (41.984, -87.750)...
# Requesting data for (41.984, -87.740)...
# Requesting data for (41.984, -87.730)...
# Requesting data for (41.984, -87.720)...
# Requesting data for (41.984, -87.710)...
# Requesting data for (41.984, -87.700)...
# Requesting data for (41.984, -87.690)...
# Requesting data for (41.984, -87.680)...
# Requesting data for (41.984, -87.670)...
# Requesting data for (41.984, -87.660)...
# Requesting data for (41.984, -87.650)...
# Requesting data for (41.984, -87.640)...
# Requesting data for (41.984, -87.630)...
# Requesting data for (41.984, -87.620)...
# Requesting data for (41.984, -87.610)...
# Requesting data for (41.984, -87.600)...
# Requesting data for (41.984, -87.590)...
# Requesting data for (41.984, -87.580)...
# Requesting data for (41.984, -87.570)...
# Requesting data for (41.984, -87.560)...
# Requesting data for (41.984, -87.550)...
# Requesting data for (41.984, -87.540)...
# Requesting data for (41.984, -87.530)...
# Requesting data for (41.994, -87.940)...
# Requesting data for (41.994, -87.930)...
# Requesting data for (41.994, -87.920)...
# Requesting data for (41.994, -87.910)...
# Requesting data for (41.994, -87.900)...
# Requesting data for (41.994, -87.890)...
# Requesting data for (41.994, -87.880)...
# Requesting data for (41.994, -87.870)...
# Requesting data for (41.994, -87.860)...
# Requesting data for (41.994, -87.850)...
# Requesting data for (41.994, -87.840)...
# Requesting data for (41.994, -87.830)...
# Requesting data for (41.994, -87.820)...
# Requesting data for (41.994, -87.810)...
# Requesting data for (41.994, -87.800)...
# Requesting data for (41.994, -87.790)...
# Requesting data for (41.994, -87.780)...
# Requesting data for (41.994, -87.770)...
# Requesting data for (41.994, -87.760)...
# Requesting data for (41.994, -87.750)...
# Requesting data for (41.994, -87.740)...
# Requesting data for (41.994, -87.730)...
# Requesting data for (41.994, -87.720)...
# Requesting data for (41.994, -87.710)...
# Requesting data for (41.994, -87.700)...
# Requesting data for (41.994, -87.690)...
# Requesting data for (41.994, -87.680)...
# Requesting data for (41.994, -87.670)...
# Requesting data for (41.994, -87.660)...
# Requesting data for (41.994, -87.650)...
# Requesting data for (41.994, -87.640)...
# Requesting data for (41.994, -87.630)...
# Requesting data for (41.994, -87.620)...
# Requesting data for (41.994, -87.610)...
# Requesting data for (41.994, -87.600)...
# Requesting data for (41.994, -87.590)...
# Requesting data for (41.994, -87.580)...
# Requesting data for (41.994, -87.570)...
# Requesting data for (41.994, -87.560)...
# Requesting data for (41.994, -87.550)...
# Requesting data for (41.994, -87.540)...
# Requesting data for (41.994, -87.530)...
# Requesting data for (42.004, -87.940)...
# Requesting data for (42.004, -87.930)...
# Requesting data for (42.004, -87.920)...
# Requesting data for (42.004, -87.910)...
# Requesting data for (42.004, -87.900)...
# Requesting data for (42.004, -87.890)...
# Requesting data for (42.004, -87.880)...
# Requesting data for (42.004, -87.870)...
# Requesting data for (42.004, -87.860)...
# Requesting data for (42.004, -87.850)...
# Requesting data for (42.004, -87.840)...
# Requesting data for (42.004, -87.830)...
# Requesting data for (42.004, -87.820)...
# Requesting data for (42.004, -87.810)...
# Requesting data for (42.004, -87.800)...
# Requesting data for (42.004, -87.790)...
# Requesting data for (42.004, -87.780)...
# Requesting data for (42.004, -87.770)...
# Requesting data for (42.004, -87.760)...
# Requesting data for (42.004, -87.750)...
# Requesting data for (42.004, -87.740)...
# Requesting data for (42.004, -87.730)...
# Requesting data for (42.004, -87.720)...
# Requesting data for (42.004, -87.710)...
# Requesting data for (42.004, -87.700)...
# Requesting data for (42.004, -87.690)...
# Requesting data for (42.004, -87.680)...
# Requesting data for (42.004, -87.670)...
# Requesting data for (42.004, -87.660)...
# Requesting data for (42.004, -87.650)...
# Requesting data for (42.004, -87.640)...
# Requesting data for (42.004, -87.630)...
# Requesting data for (42.004, -87.620)...
# Requesting data for (42.004, -87.610)...
# Requesting data for (42.004, -87.600)...
# Requesting data for (42.004, -87.590)...
# Requesting data for (42.004, -87.580)...
# Requesting data for (42.004, -87.570)...
# Requesting data for (42.004, -87.560)...
# Requesting data for (42.004, -87.550)...
# Requesting data for (42.004, -87.540)...
# Requesting data for (42.004, -87.530)...
# Requesting data for (42.014, -87.940)...
# Requesting data for (42.014, -87.930)...
# Requesting data for (42.014, -87.920)...
# Requesting data for (42.014, -87.910)...
# Requesting data for (42.014, -87.900)...
# Requesting data for (42.014, -87.890)...
# Requesting data for (42.014, -87.880)...
# Requesting data for (42.014, -87.870)...
# Requesting data for (42.014, -87.860)...
# Requesting data for (42.014, -87.850)...
# Requesting data for (42.014, -87.840)...
# Requesting data for (42.014, -87.830)...
# Requesting data for (42.014, -87.820)...
# Requesting data for (42.014, -87.810)...
# Requesting data for (42.014, -87.800)...
# Requesting data for (42.014, -87.790)...
# Requesting data for (42.014, -87.780)...
# Requesting data for (42.014, -87.770)...
# Requesting data for (42.014, -87.760)...
# Requesting data for (42.014, -87.750)...
# Requesting data for (42.014, -87.740)...
# Requesting data for (42.014, -87.730)...
# Requesting data for (42.014, -87.720)...
# Requesting data for (42.014, -87.710)...
# Requesting data for (42.014, -87.700)...
# Requesting data for (42.014, -87.690)...
# Requesting data for (42.014, -87.680)...
# Requesting data for (42.014, -87.670)...
# Requesting data for (42.014, -87.660)...
# Requesting data for (42.014, -87.650)...
# Requesting data for (42.014, -87.640)...
# Requesting data for (42.014, -87.630)...
# Requesting data for (42.014, -87.620)...
# Requesting data for (42.014, -87.610)...
# Requesting data for (42.014, -87.600)...
# Requesting data for (42.014, -87.590)...
# Requesting data for (42.014, -87.580)...
# Requesting data for (42.014, -87.570)...
# Requesting data for (42.014, -87.560)...
# Requesting data for (42.014, -87.550)...
# Requesting data for (42.014, -87.540)...
# Requesting data for (42.014, -87.530)...
# All regional data saved to 'chicago_solar_region_data1.csv'

# %%
#CLEAN THE DATA
import pandas as pd

# Load the CSV
df = pd.read_csv("cook_solar.csv") 

# Convert all values to numeric if possible, coerce errors (just in case)
df = df.apply(pd.to_numeric, errors='coerce')

# Filter out rows where ANY column has -999.0
df_cleaned = df[~(df == -999.0).any(axis=1)]

# Save the cleaned data
df_cleaned.to_csv("cleaned_file.csv", index=False)

# %%
# Convert YearMonth to year and month
df['Year'] = df['YearMonth'].astype(str).str[:4].astype(int)
df['Month'] = df['YearMonth'].astype(str).str[4:].astype(int)
# Remove the 13th month
df = df[df['Month'] != 13]

df['Month_sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_cos'] = np.cos(2 * np.pi * df['Month'] / 12)

df.head()
# Out:
#    YearMonth  Latitude  Longitude  ALLSKY_KT  ALLSKY_SFC_LW_DWN  \
# 0     201901    41.644     -87.94       0.34               6.05
# 1     201902    41.644     -87.94       0.39               6.40
# 2     201903    41.644     -87.94       0.48               6.44
# 3     201904    41.644     -87.94       0.47               7.43
# 4     201905    41.644     -87.94       0.44               8.32
#
#    ALLSKY_SFC_SW_DNI  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_PAR_TOT  \
# 0               1.98               1.38                1.19
# 1               2.32               2.12                1.66
# 2               4.19               3.62                2.33
# 3               4.23               4.53                2.97
# 4               3.64               4.85                3.38
#
#    CLRSKY_SFC_SW_DWN  Year  Month  Month_sin     Month_cos
# 0               2.82  2019      1   0.500000  8.660254e-01
# 1               3.89  2019      2   0.866025  5.000000e-01
# 2               5.46  2019      3   1.000000  6.123234e-17
# 3               6.79  2019      4   0.866025 -5.000000e-01
# 4               7.58  2019      5   0.500000 -8.660254e-01

# %%
target = 'ALLSKY_SFC_SW_DWN'  # average daily shortwave radiation

# %%
#train test split
from sklearn.model_selection import train_test_split

features = ['Latitude', 'Longitude', 'Month_sin', 'Month_cos','ALLSKY_KT', 'ALLSKY_SFC_LW_DWN']  # you can add others
x = df[features]
y = df[target]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#train the model

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
#Evaluate
from sklearn.metrics import mean_absolute_error, r2_score

y_pred = model.predict(x_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 1.1499643924374459e-14
# R² Score: 1.0

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, x, y, cv=5, scoring='neg_mean_absolute_error')
print("Cross-validated MAE:", -scores.mean())
# Out:
# Cross-validated MAE: 0.01160525562373289

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Check best parameters
print("Best parameters:", grid_search.best_params_)
model = grid_search.best_estimator_
# Out:
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Example: Predict for Chicago in April
# Inputs
lat,lon = 43.75041438389484, -84.84492681884045
month = 7
ALLSKY_KT = 0.47
ALLSKY_SFC_LW_DWN = 7.43

# Encode month cyclically
month_sin = np.sin(2 * np.pi * month / 12)
month_cos = np.cos(2 * np.pi * month / 12)

# Feature names — must match training
features = ['Latitude', 'Longitude', 'Month_sin', 'Month_cos', 'ALLSKY_KT', 'ALLSKY_SFC_LW_DWN']

# Create a DataFrame for prediction
X_new = pd.DataFrame([[lat, lon, month_sin, month_cos, ALLSKY_KT, ALLSKY_SFC_LW_DWN]], columns=features)

# Predict
prediction = model.predict(X_new)
print("Estimated daily solar energy (kWh/m²):", prediction[0])
# Out:
# Estimated daily solar energy (kWh/m²): 5.188199999999994

# %%
#SAVE THE MODEL
import joblib

# Save the best estimator
joblib.dump(model, 'solar_model.pkl')

# %%
import joblib
import math
# Load your saved model
model = joblib.load('solar_model.pkl')


# Fixed features (hardcoded)
# User input (change lat/lon values here)
lat,lon = 41.749869979845556, -88.16472257924035
month = 5
ALLSKY_KT = 0.47
ALLSKY_SFC_LW_DWN = 7.43

month_sin = np.sin(2 * np.pi * month / 12)
month_cos = np.cos(2 * np.pi * month / 12)



# Create feature vector
input_features = np.array([[lat, lon, month_sin, month_cos, ALLSKY_KT, ALLSKY_SFC_LW_DWN]])

# Predict
prediction = model.predict(input_features)

print(f"Estimated daily solar energy (kWh/m²): {prediction[0]}")
# Out:
# Estimated daily solar energy (kWh/m²): 5.119999999999993
# c:\Coding\python\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
